# %% [markdown]
# <a href="https://colab.research.google.com/github/diwakarojha/Tensorflow_Keras/blob/main/1_Introduction_Dense_C_to_F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt

# %%
model=tf.keras.models.Sequential()
model.add(Dense(1,input_shape=[1]))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1),loss='mean_squared_error',metrics=['accuracy'])

# %%
X=np.array([-40, -10,  0,  8, 15, 22,  38],dtype='float')
Y=np.array([-40,  14, 32, 46, 59, 72, 100],dtype='float')

# %%
history=model.fit(X,Y,epochs=500,verbose=0)

# %%
plt.plot(history.history['loss'])

# %%
model.predict([100.0])
# Out:
# array([[211.74744]], dtype=float32)

# %%
model.layers[0].get_weights()
# Out:
# [array([[1.7979494]], dtype=float32), array([31.952492], dtype=float32)]
